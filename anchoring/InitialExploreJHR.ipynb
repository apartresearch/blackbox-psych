# %% [markdown]
# # Exploring Anchoring
# This notebook is for doing initial explorations of how to investigate anchoring / in general conduct psychological experiments on large language models

# %%
import openai
import json
import numpy as np
import random
import asyncio
import pandas as pd

# %%
def read_json(filename: str) -> dict:
    with open(filename) as f:
        return json.load(f)

        
def get_api_key(config, keyname: str = "goose_api") -> str:
    """
    Gets the API key from the config file.
    """
    return read_json(config)[keyname]
    
def authenticate_goose(config) -> None:
    """
    Authenticates with the goose API.
    """
    api_key = get_api_key(config, keyname="goose_api")
    openai.api_key = api_key
    openai.api_base = "https://api.goose.ai/v1"

def generate_prompt(
    prompt: str, model_name: str = "gpt-neo-125m", max_tokens: int = 75, temperature=0.9
) -> str:
    """
    Generates a prompt using a model from EleutherAI.
    """
    return openai.Completion.create(
        prompt=prompt,
        engine=model_name,
        max_tokens=max_tokens,
        temperature=temperature,
    )["choices"][0]["text"]

# %%
api_key = read_json('config.json')['goose_api']

# %%
test_question = "Height of Mount Everest (in feet):"

# %%
# generate random integer between 1 and 100
true_height = 29031.7
low_num = random.randint(2000, 5000)
high_num = random.randint(50_000, 100_000)

# %%
q_prompt = f"{low_num}\n{test_question}"
print(q_prompt)
# Out:
# 3566
# Height of Mount Everest (in feet):

# %%
authenticate_goose('config.json')

# %%
answer = generate_prompt(q_prompt, max_tokens=10)

# %%
import re
def find_first_num(s: str):
    """
    Finds first integer or floating point in string
    """
    clean_s = s.replace(',', '')
    try: 
        return re.findall(r"[-+]?(?:\d*\.\d+|\d+)", clean_s)[0]
    except IndexError:
        return None

# %%
N = 10
answers = [None for _ in range(N)]
for i in range(N):
    #num = random.randint(2000, 5000)
    num = random.randint(50_000, 100_000)
    q_prompt = f"Random number: {num}\n{test_question}"
    answer = generate_prompt(q_prompt, max_tokens=10)
    answers[i] = answer

# %%
# numpy log numbers between 1 and 1_000_000
N = 3
log_nums = np.logspace(3, 5, num=10, base=10, dtype=int)
answer_dict = dict.fromkeys(log_nums)
for num in log_nums:
    prompt_list = []
    for i in range(N):
        q_prompt = f"Random number: {num}\n{test_question}"
        answer = generate_prompt(q_prompt, max_tokens=10)
        prompt_list.append(answer)
    answer_dict[num] = prompt_list

# %%
def create_prompt(num: int, question: str = test_question) -> str:
    """
    Creates a prompt for the given number.
    """
    return f"Random number: {num}\n{test_question}"

# %%
# async requests with the goose API
async def get_answer(num: int, model_type="fairseq-6-7b") -> str:
    """
    Gets an answer from the goose API.
    """
    q_prompt = create_prompt(num)
    result = generate_prompt(q_prompt, max_tokens=10, model_name=model_type)
    return result

# %%
result = asyncio.gather(*[get_answer(log_nums[0]) for _ in range(3)])

# %%
# numpy log numbers between 1 and 1_000_000
N = 10
log_nums = np.logspace(3, 5, num=10, base=10, dtype=int)
answer_dict = dict.fromkeys(log_nums)
for num in log_nums:
    answer = asyncio.gather(*[get_answer(num) for _ in range(N)])
    answer_dict[num] = answer

# %%
new_dict = {k: v.result() for k, v in answer_dict.items()}

# %%
newer_dict = {k: [find_first_num(i) for i in v] for k, v in new_dict.items()}

# %%
df = pd.concat({k: pd.Series(v) for k, v in newer_dict.items()}).reset_index().dropna()
df.columns = ["x", "ignore", "y"]
df.drop(columns=["ignore"], inplace=True)
df["y"] = df["y"].astype(float)
df.plot(x="x", y="y", kind="scatter")
df.rename(columns={"x": "anchor", "y": "model_answer"}, inplace=True)

# %%
df.to_csv("output/fairseq-6-7b_everest_answer.csv")

# %% [markdown]
# ## Exploring multiple prompts

# %%
from typing import List

async def generate_n_prompts(
    prompt, n_completions: int = 1, model_name: str = "gpt-neo-125m", max_tokens: int = 5, temperature=0.9
):
    """
    Generates a prompt using a model from EleutherAI.
    """
    return openai.Completion.create(
        prompt=prompt,
        engine=model_name,
        n = n_completions,
        max_tokens=max_tokens,
        temperature=temperature,
    )

testy = await asyncio.gather(*[generate_n_prompts("Height of Mount Everest (in feet):", n_completions=10, model_name="gpt-j-6b") for num in log_nums])

# %%
testy
# Out:
# [<OpenAIObject text_completion id=6d1623d8-9508-42a3-b1bd-73d553eba0f3 at 0x1775b4aa450> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "m",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848m\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            10
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "028",
#            " ft",
#            " ("
#          ]
#        },
#        "text": " 29,028 ft (",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " and"
#          ]
#        },
#        "text": " 8,848 and",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            5,
#            7
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "138",
#            "11",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": "\n\n13811\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "50",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Indust"
#          ]
#        },
#        "text": " 8850\n\nIndust",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            6,
#            11
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "516",
#            " feet",
#            " ("
#          ]
#        },
#        "text": " 8,516 feet (",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            6,
#            11
#          ],
#          "tokens": [
#            " 6",
#            ",",
#            "189",
#            " Feet",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 6,189 Feet\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "7"
#          ]
#        },
#        "text": " 8848\n\n7",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " feet"
#          ]
#        },
#        "text": " 8,848 feet",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            4,
#            11,
#            17
#          ],
#          "tokens": [
#            " \"",
#            " +",
#            " summit",
#            "Height",
#            ");"
#          ]
#        },
#        "text": " \" + summitHeight);",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585423,
#    "id": "6d1623d8-9508-42a3-b1bd-73d553eba0f3",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=71e6b161-d40d-4657-9b55-880187bd3e27 at 0x1775b4aa9f0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            12
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "007",
#            " feet",
#            " ("
#          ]
#        },
#        "text": " 29,007 feet (",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            3,
#            12,
#            24
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "By",
#            " personal",
#            " observation",
#            ","
#          ]
#        },
#        "text": "\nBy personal observation,",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            12
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "Height",
#            " of"
#          ]
#        },
#        "text": " 8848\nHeight of",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Average"
#          ]
#        },
#        "text": " 8848\n\nAverage",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            10
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "027",
#            " ft",
#            "."
#          ]
#        },
#        "text": " 29,027 ft.",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            6,
#            7
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "850",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8,850\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "51",
#            "m"
#          ]
#        },
#        "text": " 8,851m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            10,
#            15,
#            16
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "Elizabeth",
#            " Peak",
#            ":",
#            " 8"
#          ]
#        },
#        "text": "\nElizabeth Peak: 8",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            5,
#            7
#          ],
#          "tokens": [
#            " 85",
#            ",",
#            "8",
#            "48",
#            "The"
#          ]
#        },
#        "text": " 85,848The",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            8,
#            11
#          ],
#          "tokens": [
#            " ",
#            "bytes:'\\n'",
#            "Height",
#            " of",
#            " Everest"
#          ]
#        },
#        "text": " \nHeight of Everest",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585423,
#    "id": "71e6b161-d40d-4657-9b55-880187bd3e27",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=5fda823b-56e7-42e7-b68e-d5d91f5ae128 at 0x1775b4ae270> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            6,
#            7,
#            9
#          ],
#          "tokens": [
#            " 29",
#            "201",
#            ".",
#            "35",
#            " ("
#          ]
#        },
#        "text": " 29201.35 (",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            9
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "035",
#            " (",
#            "Google"
#          ]
#        },
#        "text": " 29,035 (Google",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " M"
#          ]
#        },
#        "text": " 8,848 M",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Height"
#          ]
#        },
#        "text": " 8848\n\nHeight",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "-",
#            "90",
#            "23"
#          ]
#        },
#        "text": " 8848-9023",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            3,
#            4
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "5",
#            ",",
#            "445"
#          ]
#        },
#        "text": "\n\n5,445",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            ".",
#            "11",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848.11\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Height"
#          ]
#        },
#        "text": " 8848\n\nHeight",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            6,
#            8
#          ],
#          "tokens": [
#            " 1",
#            ",",
#            "700",
#            "mi",
#            ","
#          ]
#        },
#        "text": " 1,700mi,",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Weight"
#          ]
#        },
#        "text": " 8848\n\nWeight",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585424,
#    "id": "5fda823b-56e7-42e7-b68e-d5d91f5ae128",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=10a3c718-f437-49ae-a4e7-113740ccea52 at 0x1775b4b3e00> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            7,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            " [",
#            "@",
#            "p"
#          ]
#        },
#        "text": " 8848 [@p",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " m"
#          ]
#        },
#        "text": " 8,848 m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            3,
#            6
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "E",
#            "lev",
#            "ation"
#          ]
#        },
#        "text": "\n\nElevation",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " ft"
#          ]
#        },
#        "text": " 8,848 ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "m"
#          ]
#        },
#        "text": " 8,848m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            8,
#            9
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            " ft",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848 ft\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "ft"
#          ]
#        },
#        "text": " 8,848ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " feet"
#          ]
#        },
#        "text": " 8,848 feet",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " ft"
#          ]
#        },
#        "text": " 8,848 ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8,848\n",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585424,
#    "id": "10a3c718-f437-49ae-a4e7-113740ccea52",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=4f352e7d-5c0c-4d3d-a9e3-2584086fa336 at 0x1775b4bef40> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "23",
#            ","
#          ]
#        },
#        "text": " 8,823,",
#        "token_index": 0
#      },
#      {
#        "finish_reason": null,
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5
#          ],
#          "tokens": [
#            " 86",
#            "64",
#            "<|endoftext|>"
#          ]
#        },
#        "text": " 8664<|endoftext|>",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8,848\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Height"
#          ]
#        },
#        "text": " 8848\n\nHeight",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            5,
#            13
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "The",
#            " highest",
#            " peak"
#          ]
#        },
#        "text": "\n\nThe highest peak",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            11,
#            12
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Reference",
#            ":",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": "\n\nReference:\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            6,
#            8
#          ],
#          "tokens": [
#            " 57",
#            ",",
#            " 8",
#            "72",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 57, 872\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " feet"
#          ]
#        },
#        "text": " 8,848 feet",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            5,
#            8,
#            10
#          ],
#          "tokens": [
#            "**",
#            " Up",
#            " to",
#            " 8",
#            ","
#          ]
#        },
#        "text": "** Up to 8,",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            8,
#            11
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Height",
#            " of",
#            " Mount"
#          ]
#        },
#        "text": "\n\nHeight of Mount",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585425,
#    "id": "4f352e7d-5c0c-4d3d-a9e3-2584086fa336",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=798a5a6c-0fc1-41f7-b466-de094c625075 at 0x1775b4c5d60> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            8
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "035",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 29,035\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            8
#          ],
#          "tokens": [
#            " 17",
#            ",",
#            "520",
#            "bytes:'\\n'",
#            "Med"
#          ]
#        },
#        "text": " 17,520\nMed",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " ft"
#          ]
#        },
#        "text": " 8,848 ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            8,
#            11
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Height",
#            " of",
#            " Mount"
#          ]
#        },
#        "text": "\n\nHeight of Mount",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "."
#          ]
#        },
#        "text": " 8,848.",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "1996"
#          ]
#        },
#        "text": " 8848\n\n1996",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "ft"
#          ]
#        },
#        "text": " 8,848ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            7,
#            10
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Great",
#            "est",
#            " height"
#          ]
#        },
#        "text": "\n\nGreatest height",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            8,
#            11
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Height",
#            " of",
#            " Mount"
#          ]
#        },
#        "text": "\n\nHeight of Mount",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            12
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "002",
#            " feet",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 29,002 feet\n",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585425,
#    "id": "798a5a6c-0fc1-41f7-b466-de094c625075",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=43319b3c-e364-4216-99fe-cf06b1af6ad6 at 0x1775b4cdd60> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "\"",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848\"\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "m"
#          ]
#        },
#        "text": " 8,848m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8,848\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "\u2032",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848\u2032\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " m"
#          ]
#        },
#        "text": " 8,848 m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " ("
#          ]
#        },
#        "text": " 8,848 (",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            10,
#            12
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            " feet",
#            " (",
#            "2"
#          ]
#        },
#        "text": " 8848 feet (2",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            7,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "50",
#            "ft",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8850ft\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            8,
#            14,
#            17,
#            21
#          ],
#          "tokens": [
#            " Highest",
#            " point",
#            " in",
#            " the",
#            " range"
#          ]
#        },
#        "text": " Highest point in the range",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            5,
#            8,
#            10,
#            15
#          ],
#          "tokens": [
#            " Mall",
#            "ory",
#            "'s",
#            " Peak",
#            " is"
#          ]
#        },
#        "text": " Mallory's Peak is",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585425,
#    "id": "43319b3c-e364-4216-99fe-cf06b1af6ad6",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=3f10e0bd-453b-44cc-984d-b9a9c82b4a76 at 0x1775b4dcdb0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            5,
#            13,
#            16
#          ],
#          "tokens": [
#            " (",
#            "the",
#            " surface",
#            " of",
#            " Meg"
#          ]
#        },
#        "text": " (the surface of Meg",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            10,
#            20
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            " From",
#            " Wikipedia",
#            ","
#          ]
#        },
#        "text": " 8848 From Wikipedia,",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            12
#          ],
#          "tokens": [
#            " 23",
#            ",",
#            "210",
#            " feet",
#            "."
#          ]
#        },
#        "text": " 23,210 feet.",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "\u2032"
#          ]
#        },
#        "text": " 8,848\u2032",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            3,
#            4
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "9",
#            ",",
#            "8"
#          ]
#        },
#        "text": "\n\n9,8",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            11
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            ";",
#            " Base",
#            "camp"
#          ]
#        },
#        "text": " 8848; Basecamp",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            3,
#            5
#          ],
#          "tokens": [
#            "8",
#            ",",
#            "8",
#            "48",
#            " feet"
#          ]
#        },
#        "text": "8,848 feet",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " feet"
#          ]
#        },
#        "text": " 8,848 feet",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " m"
#          ]
#        },
#        "text": " 8,848 m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            12
#          ],
#          "tokens": [
#            " 26",
#            ",",
#            "200",
#            " feet",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 26,200 feet\n",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585426,
#    "id": "3f10e0bd-453b-44cc-984d-b9a9c82b4a76",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=2c9febfc-9ad3-4cac-bd18-676bdac25791 at 0x1775b4d56d0> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            12
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "029",
#            " feet",
#            "Low"
#          ]
#        },
#        "text": " 29,029 feetLow",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " feet"
#          ]
#        },
#        "text": " 8,848 feet",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            8,
#            10
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            " ft",
#            " (",
#            "27"
#          ]
#        },
#        "text": " 8848 ft (27",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8,848\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            5,
#            8
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Sum",
#            "mit",
#            " of"
#          ]
#        },
#        "text": "\n\nSummit of",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            8,
#            11
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "length",
#            " of",
#            " mountain"
#          ]
#        },
#        "text": "\n\nlength of mountain",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "M"
#          ]
#        },
#        "text": " 8,848M",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            7,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "ft",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848ft\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            7,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            "CP",
#            "bytes:'\\n'",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 8848CP\n\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            6,
#            7
#          ],
#          "tokens": [
#            " 86",
#            "01",
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "Size"
#          ]
#        },
#        "text": " 8601\n\nSize",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585426,
#    "id": "2c9febfc-9ad3-4cac-bd18-676bdac25791",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  },
#  <OpenAIObject text_completion id=83234d7b-6be1-4e84-8dfd-7d3bbc2668ae at 0x1775b461a90> JSON: {
#    "choices": [
#      {
#        "finish_reason": "length",
#        "index": 0,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " ft"
#          ]
#        },
#        "text": " 8,848 ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 1,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            4,
#            5
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "89",
#            "1",
#            " Highest"
#          ]
#        },
#        "text": "\n\n891 Highest",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 2,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            7,
#            9
#          ],
#          "tokens": [
#            " 83",
#            "75",
#            " m",
#            " (",
#            "27"
#          ]
#        },
#        "text": " 8375 m (27",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 3,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            12
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "029",
#            " feet",
#            "bytes:'\\n'"
#          ]
#        },
#        "text": " 29,029 feet\n",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 4,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            5,
#            7,
#            8
#          ],
#          "tokens": [
#            " 88",
#            "48",
#            " (",
#            "e",
#            "lev"
#          ]
#        },
#        "text": " 8848 (elev",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 5,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            3,
#            4
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "8",
#            ",",
#            "8"
#          ]
#        },
#        "text": "\n\n8,8",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 6,
#        "logprobs": {
#          "text_offset": [
#            0,
#            3,
#            4,
#            7,
#            10
#          ],
#          "tokens": [
#            " 29",
#            ",",
#            "002",
#            " ft",
#            " ("
#          ]
#        },
#        "text": " 29,002 ft (",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 7,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            "m"
#          ]
#        },
#        "text": " 8,848m",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 8,
#        "logprobs": {
#          "text_offset": [
#            0,
#            2,
#            3,
#            4,
#            6
#          ],
#          "tokens": [
#            " 8",
#            ",",
#            "8",
#            "48",
#            " ft"
#          ]
#        },
#        "text": " 8,848 ft",
#        "token_index": 0
#      },
#      {
#        "finish_reason": "length",
#        "index": 9,
#        "logprobs": {
#          "text_offset": [
#            0,
#            1,
#            2,
#            3,
#            6
#          ],
#          "tokens": [
#            "bytes:'\\n'",
#            "bytes:'\\n'",
#            "e",
#            "lev",
#            "ation"
#          ]
#        },
#        "text": "\n\nelevation",
#        "token_index": 0
#      }
#    ],
#    "created": 1656585427,
#    "id": "83234d7b-6be1-4e84-8dfd-7d3bbc2668ae",
#    "model": "gpt-j-6b",
#    "object": "text_completion"
#  }]

# %%
[i.text for x in testy for i in x.choices]
# Out:
# [' 8848m\n\n',
#  ' 29,028 ft (',
#  ' 8,848 and',
#  '\n\n13811\n',
#  ' 8850\n\nIndust',
#  ' 8,516 feet (',
#  ' 6,189 Feet\n',
#  ' 8848\n\n7',
#  ' 8,848 feet',
#  ' " + summitHeight);',
#  ' 29,007 feet (',
#  '\nBy personal observation,',
#  ' 8848\nHeight of',
#  ' 8848\n\nAverage',
#  ' 29,027 ft.',
#  ' 8,850\n\n',
#  ' 8,851m',
#  '\nElizabeth Peak: 8',
#  ' 85,848The',
#  ' \nHeight of Everest',
#  ' 29201.35 (',
#  ' 29,035 (Google',
#  ' 8,848 M',
#  ' 8848\n\nHeight',
#  ' 8848-9023',
#  '\n\n5,445',
#  ' 8848.11\n',
#  ' 8848\n\nHeight',
#  ' 1,700mi,',
#  ' 8848\n\nWeight',
#  ' 8848 [@p',
#  ' 8,848 m',
#  '\n\nElevation',
#  ' 8,848 ft',
#  ' 8,848m',
#  ' 8848 ft\n\n',
#  ' 8,848ft',
#  ' 8,848 feet',
#  ' 8,848 ft',
#  ' 8,848\n',
#  ' 8,823,',
#  ' 8664<|endoftext|>',
#  ' 8,848\n',
#  ' 8848\n\nHeight',
#  '\n\nThe highest peak',
#  '\n\nReference:\n',
#  ' 57, 872\n',
#  ' 8,848 feet',
#  '** Up to 8,',
#  '\n\nHeight of Mount',
#  ' 29,035\n\n',
#  ' 17,520\nMed',
#  ' 8,848 ft',
#  '\n\nHeight of Mount',
#  ' 8,848.',
#  ' 8848\n\n1996',
#  ' 8,848ft',
#  '\n\nGreatest height',
#  '\n\nHeight of Mount',
#  ' 29,002 feet\n',
#  ' 8848"\n\n',
#  ' 8,848m',
#  ' 8,848\n',
#  ' 8848′\n\n',
#  ' 8,848 m',
#  ' 8,848 (',
#  ' 8848 feet (2',
#  ' 8850ft\n\n',
#  ' Highest point in the range',
#  " Mallory's Peak is",
#  ' (the surface of Meg',
#  ' 8848 From Wikipedia,',
#  ' 23,210 feet.',
#  ' 8,848′',
#  '\n\n9,8',
#  ' 8848; Basecamp',
#  '8,848 feet',
#  ' 8,848 feet',
#  ' 8,848 m',
#  ' 26,200 feet\n',
#  ' 29,029 feetLow',
#  ' 8,848 feet',
#  ' 8848 ft (27',
#  ' 8,848\n',
#  '\n\nSummit of',
#  '\n\nlength of mountain',
#  ' 8,848M',
#  ' 8848ft\n\n',
#  ' 8848CP\n\n',
#  ' 8601\n\nSize',
#  ' 8,848 ft',
#  '\n\n891 Highest',
#  ' 8375 m (27',
#  ' 29,029 feet\n',
#  ' 8848 (elev',
#  '\n\n8,8',
#  ' 29,002 ft (',
#  ' 8,848m',
#  ' 8,848 ft',
#  '\n\nelevation']

# %%
test_prompts = [create_prompt(num) for num in log_nums]
N_REP = 20
testytest_fairseq = generate_prompts(test_prompts, n_completions=N_REP, model_name="fairseq-6-7b")

# %%
anchors = np.repeat(log_nums, N_REP)
answers = [result.text for result in testytest_fairseq.choices]
float_answers = [find_first_num(answer) for answer in answers]

# %%
new_df = pd.DataFrame({"anchor": anchors, "model_answer": float_answers}).dropna()
new_df["model_answer"] = new_df["model_answer"].astype(float)
new_df[new_df["model_answer"] < 100_000].plot(x="anchor", y="model_answer", kind="scatter")
# Out:
# <AxesSubplot:xlabel='anchor', ylabel='model_answer'>

# %%
new_df.to_csv("output/fairseq-6-7b_everest_answer_2.csv", index=False)
